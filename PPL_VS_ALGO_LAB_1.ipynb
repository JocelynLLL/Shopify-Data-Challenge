# %% [markdown]
# <a href="https://colab.research.google.com/github/JocelynLLL/Shopify-Data-Challenge/blob/main/PPL_VS_ALGO_LAB_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import vega_datasets
movies = vega_datasets.data.movies()

# %%
movies.columns
# Out:
# Index(['Title', 'US_Gross', 'Worldwide_Gross', 'US_DVD_Sales',
#        'Production_Budget', 'Release_Date', 'MPAA_Rating', 'Running_Time_min',
#        'Distributor', 'Source', 'Major_Genre', 'Creative_Type', 'Director',
#        'Rotten_Tomatoes_Rating', 'IMDB_Rating', 'IMDB_Votes'],
#       dtype='object')

# %%
movies.describe()
# Out:
#            US_Gross  Worldwide_Gross  ...  IMDB_Rating     IMDB_Votes
# count  3.194000e+03     3.194000e+03  ...  2988.000000    2988.000000
# mean   4.400209e+07     8.534340e+07  ...     6.283467   29908.644578
# std    6.255531e+07     1.499473e+08  ...     1.252290   44937.582335
# min    0.000000e+00     0.000000e+00  ...     1.400000      18.000000
# 25%    5.493221e+06     8.031285e+06  ...     5.600000    4828.500000
# 50%    2.201947e+07     3.116893e+07  ...     6.400000   15106.000000
# 75%    5.609176e+07     9.728380e+07  ...     7.200000   35810.500000
# max    7.601676e+08     2.767891e+09  ...     9.200000  519541.000000
#
# [8 rows x 8 columns]

# %%
movies['Major_Genre'].hist(xrot = 45)

# %%
movies[movies['Major_Genre'] == 'Black Comedy']
# Out:
#                            Title    US_Gross  ...  IMDB_Rating  IMDB_Votes
# 0                 The Land Girls    146083.0  ...          6.1      1071.0
# 1         First Love, Last Rites     10876.0  ...          6.9       207.0
# 2     I Married a Strange Person    203134.0  ...          6.8       865.0
# 3           Let's Talk About Sex    373615.0  ...          NaN         NaN
# 4                           Slam   1009819.0  ...          3.4       165.0
# ...                          ...         ...  ...          ...         ...
# 3196  Zack and Miri Make a Porno  31452765.0  ...          7.0     55687.0
# 3197                      Zodiac  33080084.0  ...          NaN         NaN
# 3198                        Zoom  11989328.0  ...          3.4      7424.0
# 3199         The Legend of Zorro  45575336.0  ...          5.7     21161.0
# 3200           The Mask of Zorro  93828745.0  ...          6.7      4789.0
#
# [3201 rows x 16 columns]

# %%
# three diff category for comedy?

# %%
movies[movies['Title'] == 'Blazing Saddles'] # comedy even though its also western
# Out:
#                Title     US_Gross  ...  IMDB_Rating  IMDB_Votes
# 139  Blazing Saddles  119500000.0  ...          7.8     45771.0
#
# [1 rows x 16 columns]

# %%
movies['MPAA_Rating'].hist()

# %%
movies['Source'].value_counts()
# Out:
# Original Screenplay              1536
# Based on Book/Short Story         657
# Based on Real Life Events         186
# Remake                            126
# Based on TV                       106
# Based on Comic/Graphic Novel       82
# Based on Play                      55
# Based on Game                      22
# Traditional/Legend/Fairytale       16
# Based on Magazine Article          10
# Based on Musical/Opera              9
# Based on Short Film                 8
# Spin-Off                            8
# Based on Factual Book/Article       6
# Disney Ride                         4
# Compilation                         3
# Based on Toy                        1
# Musical Group Movie                 1
# Name: Source, dtype: int64

# %%
movies[movies['Source'] == 'Based on Game']['Rotten_Tomatoes_Rating']
# Out:
# 624     35.0
# 865      NaN
# 902     13.0
# 1150     1.0
# 1604    34.0
# 1610    19.0
# 1651     NaN
# 1652     NaN
# 1748     NaN
# 1903     NaN
# 2351     7.0
# 2492    17.0
# 2565     NaN
# 2598     4.0
# 2623     NaN
# 2624    22.0
# 2625     NaN
# 2626    34.0
# 2733    29.0
# 2979     NaN
# 2980     NaN
# 3136    11.0
# Name: Rotten_Tomatoes_Rating, dtype: float64

# %%
movies[movies['Source'] == 'Based on Game']['Worldwide_Gross'] - movies[movies['Source'] == 'Based on Game']['Production_Budget']
# Out:
# 624     102133227.0
# 865     -21155093.0
# 902      64423000.0
# 1150    -11821431.0
# 1604    -27329140.0
# 1610    -15387663.0
# 1651    -14090178.0
# 1652     -1228035.0
# 1748    -51868170.0
# 1903      6767816.0
# 2351     21327406.0
# 2492     50761789.0
# 2565    135055643.0
# 2598    -22594580.0
# 2623     78940078.0
# 2624    101162920.0
# 2625     92068993.0
# 2626     68787401.0
# 2733     49982632.0
# 2979     66453758.0
# 2980    180644183.0
# 3136    -18421978.0
# dtype: float64

# %%
# Out:
# 624      20000000.0
# 865      42000000.0
# 902      35000000.0
# 1150     20000000.0
# 1604     30000000.0
# 1610     70000000.0
# 1651     15000000.0
# 1652     35000000.0
# 1748    137000000.0
# 1903      7000000.0
# 2351     30000000.0
# 2492     35000000.0
# 2565    200000000.0
# 2598     25000000.0
# 2623     50000000.0
# 2624     45000000.0
# 2625     57500000.0
# 2626     35000000.0
# 2733     50000000.0
# 2979     90000000.0
# 2980     94000000.0
# 3136     30000000.0
# Name: Production_Budget, dtype: float64
